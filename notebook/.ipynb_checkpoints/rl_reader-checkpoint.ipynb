# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn
import csv
import logging
log = logging.getLogger()
log.setLevel(logging.DEBUG)

pd.options.display.max_rows = 1000
pd.options.display.colwidth = 100


files = ['paris']

# %%
def rl_parse():
    data = {}
    for file in files:
        log.info("parsing file: ../data/{}-openie.rl".format(file))
        my_cols = ["Confidence", "Context", "Subject", "Predicate", "Object", "Other_arg", "Temporal", "Spatial", "Sentence_id", "Sentence"]
        values = pd.read_csv("../data/{}-openie.rl".format(file), names=my_cols, sep='\t', quoting=csv.QUOTE_NONE)
        values.drop(values.columns[[0, 1, 8]], axis=1, inplace=True)
        data[file] = values
    return data

# %%
data = rl_parse()
# Out:
# INFO:root:parsing file: ../data/paris-openie.rl

# %%
data['paris']
# Out:
#                                                 Subject  \
# 0                                         French: [paʁi
# 1                                              [paʁi] )
# 2                                                    it
# 3                the centre of the Île-de-France region
# 4                                     The City of Paris
# 5                                     The City of Paris
# 6                                      The Paris Region
# 7                                      The Paris Region
# 8                                                    It
# 9                                                 Paris
# 10                   a Celtic people called the Parisii
# 11                                                Paris
# 12                                                Paris
# 13                                                   it
# 14                                                   it
# 15                                           a position
# ...
